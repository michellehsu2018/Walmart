# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("train.csv",dtype = {'Upc': str, 'FinelineNumber':"category", 'TripType':"category" , 'Weekday':"category"})
test = pd.read_csv("test.csv",dtype = {'Upc': str, 'FinelineNumber':"category", 'TripType':"category" , 'Weekday':"category"})

# %%
all_data = pd.concat([train,test])
all_data.reset_index(inplace=True,drop=True)

# %%
all_data.drop(['TripType', 'Upc'], axis = 1, inplace = True)

# %%
group_vn = all_data.groupby(['VisitNumber', 'FinelineNumber']).agg({'FinelineNumber':'count'}, as_index=False)

# %%
group_data = group_vn.unstack()

# %%
del group_data['FinelineNumber'].index.name

# %%
test = group_data['FinelineNumber']

# %%
test.head()
# Out:
# FinelineNumber   0   1  10  100  1000  1001  1002  1003  1004  1005  ...   \
# 1              NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2              NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3              NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4              NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5              NaN NaN NaN  NaN   1.0   NaN   NaN   NaN   NaN   NaN  ...
#
# FinelineNumber  9969  9970  9971  9974  9975  998  9991  9997  9998  9999
# 1                NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 2                NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 3                NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 4                NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 5                NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 5353 columns]

# %%
test.columns.name = 'VisitNumber'

# %%
test.head(6)
# Out:
# VisitNumber   0   1  10  100  1000  1001  1002  1003  1004  1005  ...   9969  \
# 1           NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 2           NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 3           NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 4           NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 5           NaN NaN NaN  NaN   1.0   NaN   NaN   NaN   NaN   NaN  ...    NaN
# 6           NaN NaN NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...    NaN
#
# VisitNumber  9970  9971  9974  9975  998  9991  9997  9998  9999
# 1             NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 2             NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 3             NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 4             NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 5             NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# ...
